# %%
import pandas as pd

# %%
df = pd.read_csv("/home/jovyan/shared/datasets/RetailBanking/customer_panel_train.csv")
customers_all = pd.read_csv("/home/jovyan/shared/datasets/RetailBanking/customers_all.csv")
accounts_all = pd.read_csv("/home/jovyan/shared/datasets/RetailBanking/accounts_all.csv")

merged = (
    df
    .merge(accounts_all, left_on="CustomerID", right_on="CustomerID", how="left")
    .merge(customers_all, left_on = "CustomerID", right_on = "CustomerID", how = "left")
         )

# %%
merged[merged["CustomerID"] == 'C000009']
# Out:
#    CustomerID  Week  Utilisation  PaymentRatio  HardInquiries  DefaultLabel  \
# 26    C000009     1          0.0           0.0              0             0
# 27    C000009     1          0.0           0.0              0             0
# 28    C000009     2          0.0           0.0              0             0
# 29    C000009     2          0.0           0.0              0             0
# 30    C000009     3          0.0           0.0              0             0
# 31    C000009     3          0.0           0.0              0             0
# 32    C000009     4          0.0           0.0              1             0
# 33    C000009     4          0.0           0.0              1             0
# 34    C000009     5          0.0           0.0              0             0
# 35    C000009     5          0.0           0.0              0             0
# 36    C000009     6          0.0           0.0              0             0
# ...
